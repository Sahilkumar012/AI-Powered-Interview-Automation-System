# %%
    # %pip install opencv-python mediapipe ultralytics
# Out:
# Requirement already satisfied: opencv-python in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (4.11.0.86)
# Requirement already satisfied: mediapipe in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (0.10.21)
# Requirement already satisfied: ultralytics in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (8.3.146)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: absl-py in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (2.3.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (0.6.1)
# Requirement already satisfied: jaxlib in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (0.6.1)
# Requirement already satisfied: matplotlib in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (3.10.3)
# Requirement already satisfied: opencv-contrib-python in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (1.15.2)
# Requirement already satisfied: torch>=1.8.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (2.7.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (0.22.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from matplotlib->mediapipe) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from matplotlib->mediapipe) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: CFFI>=1.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: filelock in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.5.1)
# Requirement already satisfied: colorama in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: ml_dtypes>=0.5.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from jax->mediapipe) (0.5.1)
# Requirement already satisfied: opt_einsum in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: pycparser in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sahil\downloads\fyp-1\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

# %%
import numpy as np

# %%
from ultralytics import YOLO

# %%
import mediapipe as mp

# %%
# final model for face/head and eye tracking


# Load YOLO model
model = YOLO("yolov8n.pt")  # Use a face-trained model if you have one

# Initialize webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Cannot open webcam.")
    exit()

# Initialize MediaPipe Face Mesh
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False,
                                  max_num_faces=1,
                                  refine_landmarks=True,
                                  min_detection_confidence=0.5,
                                  min_tracking_confidence=0.5)

def get_head_pose(image, landmarks):
    image_points = np.array([
        landmarks[1],    # Nose tip
        landmarks[152],  # Chin
        landmarks[33],   # Right eye outer corner
        landmarks[263],  # Left eye outer corner
        landmarks[78],   # Right mouth corner
        landmarks[308]   # Left mouth corner
    ], dtype="double")

    model_points = np.array([
        (0.0, 0.0, 0.0),             # Nose tip
        (0.0, -330.0, -65.0),        # Chin
        (225.0, 170.0, -135.0),      # Right eye outer corner
        (-225.0, 170.0, -135.0),     # Left eye outer corner
        (150.0, -150.0, -125.0),     # Right mouth corner
        (-150.0, -150.0, -125.0)     # Left mouth corner
    ])

    focal_length = image.shape[1]
    center = (image.shape[1] / 2, image.shape[0] / 2)
    camera_matrix = np.array([
        [focal_length, 0, center[0]],
        [0, focal_length, center[1]],
        [0, 0, 1]
    ], dtype="double")

    dist_coeffs = np.zeros((4, 1))
    success, rvec, _, _ = cv2.solvePnPRansac(
        model_points, image_points, camera_matrix, dist_coeffs)

    rmat, _ = cv2.Rodrigues(rvec)
    proj_matrix = np.hstack((rmat, np.zeros((3, 1))))
    _, _, _, _, _, _, angles = cv2.decomposeProjectionMatrix(proj_matrix)

    return angles  # pitch, yaw, roll

# ✅ Updated eye direction using iris tracking
def get_eye_direction(landmarks, iw):
    try:
        right_iris_center = landmarks[468]  # Iris center
        right_eye_inner = landmarks[133]
        right_eye_outer = landmarks[33]

        eye_width = right_eye_outer[0] - right_eye_inner[0]
        if eye_width == 0:
            return "Undetected"

        iris_relative_pos = (right_iris_center[0] - right_eye_inner[0]) / eye_width

        if iris_relative_pos < 0.40:
            return "Looking Left"
        elif iris_relative_pos > 0.60:
            return "Looking Right"
        else:
            return "Looking Center"
    except:
        return "Undetected"

print("Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = model(frame)

    for box in results[0].boxes.xyxy:
        x1, y1, x2, y2 = map(int, box)
        face = frame[y1:y2, x1:x2]

        if face.shape[0] == 0 or face.shape[1] == 0:
            continue

        face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        result_mesh = face_mesh.process(face_rgb)

        if result_mesh.multi_face_landmarks:
            for landmarks in result_mesh.multi_face_landmarks:
                ih, iw, _ = face.shape
                coords = [(p.x * iw, p.y * ih) for p in landmarks.landmark]

                try:
                    angles = get_head_pose(face, coords)
                    pitch, yaw, roll = [a[0] for a in angles]

                    if abs(yaw) > 10:  # ✅ Increased yaw threshold for more reliable detection
                        cheat = "⚠️ Head turned!"
                        print(f"Yaw: {yaw:.2f} - Cheat: {cheat}")
                    elif abs(pitch) > 7:
                        cheat = "⚠️ Looking up/down!"
                        print(f"Pitch: {pitch:.2f} - Cheat: {cheat}")
                    else:
                        cheat = ""
                except:
                    cheat = "Head Pose Error"
                    print("Head Pose Error")

                eye_dir = get_eye_direction(coords, iw)
                if eye_dir != "Looking Center":
                    cheat = f"⚠️ {eye_dir}"
                    print(f"Eye Direction: {eye_dir} - Cheat: {cheat}")
                else:
                    cheat = ""
                    print("Eye Direction: Looking Center")

                # Draw box and alert
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, eye_dir, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
                if cheat:
                    cv2.putText(frame, cheat, (x1, y2 + 20),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

    cv2.imshow("YOLO + MediaPipe Cheat Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'q' to quit.
#
# 0: 480x640 3 persons, 1 kite, 1 clock, 233.0ms
# Speed: 5.7ms preprocess, 233.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 27.08 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Pitch: 13.34 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
# Yaw: 23.62 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 2 persons, 1 clock, 187.5ms
# Speed: 3.8ms preprocess, 187.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 42.56 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 2 persons, 2 clocks, 211.2ms
# Speed: 2.7ms preprocess, 211.2ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 23.15 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 10.44 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 2 persons, 1 clock, 191.1ms
# Speed: 2.9ms preprocess, 191.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 18.64 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: -24.35 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 186.5ms
# Speed: 2.8ms preprocess, 186.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 clock, 159.3ms
# Speed: 4.5ms preprocess, 159.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -14.34 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Pitch: -20.87 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 clock, 160.0ms
# Speed: 2.5ms preprocess, 160.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 clock, 156.6ms
# Speed: 2.6ms preprocess, 156.6ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 clock, 157.2ms
# Speed: 3.1ms preprocess, 157.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -11.19 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 clock, 155.1ms
# Speed: 3.6ms preprocess, 155.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -16.04 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 clock, 153.7ms
# Speed: 2.6ms preprocess, 153.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -25.78 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 clock, 170.9ms
# Speed: 2.9ms preprocess, 170.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -31.47 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 chair, 1 clock, 157.0ms
# Speed: 2.9ms preprocess, 157.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -35.46 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 clock, 160.9ms
# Speed: 2.6ms preprocess, 160.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -34.89 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 clock, 156.9ms
# Speed: 2.7ms preprocess, 156.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -35.81 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 clock, 154.9ms
# Speed: 2.7ms preprocess, 154.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -44.54 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 clock, 159.4ms
# Speed: 2.6ms preprocess, 159.4ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -43.70 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 clock, 158.9ms
# Speed: 3.1ms preprocess, 158.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -44.57 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 3 persons, 1 clock, 155.5ms
# Speed: 3.2ms preprocess, 155.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -47.63 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 4 persons, 1 clock, 157.1ms
# Speed: 2.9ms preprocess, 157.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Yaw:
ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -21.32 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 11.16 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 6 persons, 1 chair, 177.5ms
# Speed: 3.6ms preprocess, 177.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Eye Direction: Looking Center
# Yaw: 12.71 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 8 persons, 1 laptop, 177.4ms
# Speed: 3.1ms preprocess, 177.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -61.45 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
# Yaw: 14.21 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
# Yaw: -42.11 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 7 persons, 1 chair, 1 laptop, 169.5ms
# Speed: 3.3ms preprocess, 169.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -18.43 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
# Eye Direction: Looking Center
#
# 0: 480x640 9 persons, 1 laptop, 181.0ms
# Speed: 3.2ms preprocess, 181.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -16.63 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Eye Direction: Looking Center
# Yaw: -53.58 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 6 persons, 180.3ms
# Speed: 3.1ms preprocess, 180.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -37.86 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 8 persons, 1 chair, 196.2ms
# Speed: 3.6ms preprocess, 196.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -29.28 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 9 persons, 1 chair, 169.0ms
# Speed: 3.2ms preprocess, 169.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -26.63 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: -42.54 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 6 persons, 1 chair, 181.2ms
# Speed: 3.3ms preprocess, 181.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -21.22 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: -35.47 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 6 persons, 2 chairs, 166.6ms
# Speed: 3.4ms preprocess, 166.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -14.65 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: -35.38 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 7 persons, 1 chair, 172.0ms
# Speed: 3.2ms preprocess, 172.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -63.15 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
# Yaw: -44.61 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: -48.40 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 8 persons, 165.4ms
# Speed: 3.0ms preprocess, 165.4ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -41.90 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 8 persons, 1 backpack, 1 chair, 167.0ms
# Speed: 3.6ms preprocess, 167.0ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -14.11 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 12.31 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
# Yaw: 15.31 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 5 persons, 1 handbag, 171.9ms
# Speed: 3.6ms preprocess, 171.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -16.24 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Pitch: -16.09 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
#
# 0: 480x640 2 persons, 162.7ms
# Speed: 2.9ms preprocess, 162.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -15.24 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 2 persons, 207.6ms
# Speed: 3.0ms preprocess, 207.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 bottle, 1 cup, 205.9ms
# Speed: 4.6ms preprocess, 205.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -39.73 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 4 persons, 1 cup, 1 bowl, 208.5ms
# Speed: 3.7ms preprocess, 208.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -34.11 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 43.98 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 bowl, 3 laptops, 341.4ms
# Speed: 5.6ms preprocess, 341.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 14.99 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
# Yaw: 33.72 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 bowl, 1 laptop, 206.9ms
# Speed: 4.0ms preprocess, 206.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Eye Direction: Looking Center
# Yaw: 36.48 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 5 persons, 1 cup, 1 bowl, 1 chair, 1 laptop, 158.5ms
# Speed: 3.2ms preprocess, 158.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: 13.64 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
# Yaw: 36.78 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 44.06 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 170.2ms
# Speed: 3.4ms preprocess, 170.2ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -25.26 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
# Yaw: 38.90 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 chair, 1 laptop, 178.0ms
# Speed: 3.5ms preprocess, 178.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -17.95 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 40.96 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 5 persons, 1 cup, 1 bowl, 1 laptop, 167.9ms
# Speed: 3.0ms preprocess, 167.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: 7.79 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
# Yaw: 38.26 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 43.56 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 171.1ms
# Speed: 3.1ms preprocess, 171.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -36.68 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
# Yaw: 37.88 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 6 persons, 1 cup, 1 laptop, 170.3ms
# Speed: 3.3ms preprocess, 170.3ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 41.02 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 41.44 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 33.39 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
# Yaw: 54.70 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 5 persons, 1 cup, 1 chair, 1 laptop, 169.4ms
# Speed: 3.1ms preprocess, 169.4ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -32.81 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
# Yaw: 45.24 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 20.43 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 186.6ms
# Speed: 3.2ms preprocess, 186.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -12.10 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 41.53 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 5 persons, 1 cup, 1 laptop, 164.1ms
# Speed: 3.4ms preprocess, 164.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 42.58 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 34.88 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 35.50 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 6 persons, 1 cup, 1 laptop, 176.3ms
# Speed: 3.7ms preprocess, 176.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -15.22 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 35.27 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
# Yaw: 36.54 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 chair, 1 laptop, 171.8ms
# Speed: 3.2ms preprocess, 171.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -15.44 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 37.31 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 175.9ms
# Speed: 4.1ms preprocess, 175.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -25.75 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 44.00 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 173.6ms
# Speed: 3.0ms preprocess, 173.6ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -23.32 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 37.43 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 181.7ms
# Speed: 3.0ms preprocess, 181.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -24.40 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 43.03 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 177.4ms
# Speed: 3.4ms preprocess, 177.4ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -21.29 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 52.31 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 5 persons, 1 cup, 1 laptop, 172.6ms
# Speed: 3.2ms preprocess, 172.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -22.35 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 41.20 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 5 persons, 1 cup, 1 laptop, 160.3ms
# Speed: 3.3ms preprocess, 160.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: 7.92 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
# Yaw: 40.77 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
# Yaw: 34.80 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 176.0ms
# Speed: 3.3ms preprocess, 176.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -17.18 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 35.10 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 1 laptop, 171.8ms
# Speed: 3.5ms preprocess, 171.8ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -10.13 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 33.11 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 cup, 2 chairs, 1 dining table, 1 laptop, 184.6ms
# Speed: 3.3ms preprocess, 184.6ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -18.58 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 39.03 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 32.02 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 2 persons, 171.3ms
# Speed: 2.9ms preprocess, 171.3ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -10.11 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 5 persons, 171.1ms
# Speed: 3.4ms preprocess, 171.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Pitch: -10.98 - Cheat: ⚠️ Looking up/down!
# Eye Direction: Looking Center
#
# 0: 480x640 6 persons, 176.6ms
# Speed: 3.4ms preprocess, 176.6ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -13.31 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: -15.60 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 6 persons, 1 chair, 165.2ms
# Speed: 3.7ms preprocess, 165.2ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -21.98 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 5 persons, 1 chair, 181.4ms
# ...
# Speed: 3.5ms preprocess, 193.3ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 58.88 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 1 person, 1 laptop, 192.5ms
# Speed: 4.1ms preprocess, 192.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 49.93 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 198.7ms
# Speed: 3.6ms preprocess, 198.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 51.83 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 2 persons, 1 tv, 1 laptop, 201.7ms
# Speed: 3.8ms preprocess, 201.7ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 55.28 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
# Yaw: 54.47 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 1 person, 214.5ms
# Speed: 3.1ms preprocess, 214.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 58.98 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 1 person, 1 laptop, 191.4ms
# Speed: 3.2ms preprocess, 191.4ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 71.09 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640
ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -59.54 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 2 persons, 1 cup, 198.9ms
# Speed: 6.3ms preprocess, 198.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -57.94 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 cup, 209.9ms
# Speed: 3.3ms preprocess, 209.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -56.56 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 210.6ms
# Speed: 3.6ms preprocess, 210.6ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -55.10 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 cup, 209.8ms
# Speed: 3.3ms preprocess, 209.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -53.41 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 cup, 221.4ms
# Speed: 3.4ms preprocess, 221.4ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -56.40 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 laptop, 227.1ms
# Speed: 3.5ms preprocess, 227.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -57.28 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
# Yaw: 22.90 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 cup, 211.1ms
# Speed: 3.9ms preprocess, 211.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -60.29 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
# Yaw: 35.62 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 cup, 201.3ms
# Speed: 3.8ms preprocess, 201.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -75.80 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 cup, 1 laptop, 208.3ms
# Speed: 3.3ms preprocess, 208.3ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -63.66 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 216.3ms
# Speed: 4.1ms preprocess, 216.3ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -61.66 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 cup, 209.8ms
# Speed: 3.5ms preprocess, 209.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -61.12 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 cup, 1 laptop, 225.9ms
# Speed: 3.6ms preprocess, 225.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -60.09 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 cup, 269.6ms
# Speed: 4.3ms preprocess, 269.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -58.57 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
# Yaw: 46.51 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 cup, 1 laptop, 253.6ms
# Speed: 4.5ms preprocess, 253.6ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -59.78 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 cup, 241.1ms
# Speed: 11.8ms preprocess, 241.1ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -59.98 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 cup, 277.1ms
# Speed: 3.9ms preprocess, 277.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -59.05 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
# Yaw: 37.41 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 cup, 1 laptop, 286.1ms
# Speed: 5.1ms preprocess, 286.1ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -48.89 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 cup, 1 refrigerator, 254.0ms
# Speed: 4.0ms preprocess, 254.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -42.05 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
# Yaw: 45.77 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 cup, 1 tv, 1 laptop, 222.0ms
# Speed: 4.8ms preprocess, 222.0ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -35.72 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
#
# 0: 480x640 1 person, 1 cup, 1 tv, 224.1ms
# Speed: 4.1ms preprocess, 224.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -37.64 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Right - Cheat: ⚠️ Looking Right
# Yaw: 49.58 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 cup, 216.2ms
# Speed: 3.3ms preprocess, 216.2ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -39.74 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 cup, 217.1ms
# Speed: 3.6ms preprocess, 217.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -40.58 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 38.83 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 cup, 205.2ms
# Speed: 3.6ms preprocess, 205.2ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -48.59 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 1 car, 219.0ms
# Speed: 3.7ms preprocess, 219.0ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 216.1ms
# Speed: 3.6ms preprocess, 216.1ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -14.02 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 200.5ms
# Speed: 3.1ms preprocess, 200.5ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -15.97 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 chair, 209.3ms
# Speed: 4.0ms preprocess, 209.3ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -24.94 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
#
# 0: 480x640 4 persons, 1 bowl, 1 chair, 1 couch, 228.3ms
# Speed: 3.6ms preprocess, 228.3ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -24.99 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center
# Yaw: 53.77 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Center

# %%
# # model for both eye and face but need some changes

# import cv2
# import numpy as np
# from ultralytics import YOLO
# import mediapipe as mp

# # Load YOLO model
# model = YOLO("yolov8n.pt")  # Use a face-trained model if you have one

# # Initialize webcam
# cap = cv2.VideoCapture(0)
# if not cap.isOpened():
#     print("Error: Cannot open webcam.")
#     exit()

# # Initialize MediaPipe Face Mesh
# mp_face_mesh = mp.solutions.face_mesh
# face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False,
#                                   max_num_faces=1,
#                                   refine_landmarks=True,
#                                   min_detection_confidence=0.5,
#                                   min_tracking_confidence=0.5)

# def get_head_pose(image, landmarks):
#     image_points = np.array([
#         landmarks[1],    # Nose tip
#         landmarks[152],  # Chin
#         landmarks[33],   # Right eye outer corner
#         landmarks[263],  # Left eye outer corner
#         landmarks[78],   # Right mouth corner
#         landmarks[308]   # Left mouth corner
#     ], dtype="double")

#     model_points = np.array([
#         (0.0, 0.0, 0.0),             # Nose tip
#         (0.0, -330.0, -65.0),        # Chin
#         (225.0, 170.0, -135.0),      # Right eye outer corner
#         (-225.0, 170.0, -135.0),     # Left eye outer corner
#         (150.0, -150.0, -125.0),     # Right mouth corner
#         (-150.0, -150.0, -125.0)     # Left mouth corner
#     ])

#     focal_length = image.shape[1]
#     center = (image.shape[1] / 2, image.shape[0] / 2)
#     camera_matrix = np.array([
#         [focal_length, 0, center[0]],
#         [0, focal_length, center[1]],
#         [0, 0, 1]
#     ], dtype="double")

#     dist_coeffs = np.zeros((4, 1))
#     success, rvec, _, _ = cv2.solvePnPRansac(
#         model_points, image_points, camera_matrix, dist_coeffs)

#     rmat, _ = cv2.Rodrigues(rvec)
#     proj_matrix = np.hstack((rmat, np.zeros((3, 1))))
#     _, _, _, _, _, _, angles = cv2.decomposeProjectionMatrix(proj_matrix)

#     return angles  # pitch, yaw, roll

# # ✅ Updated eye direction using iris tracking
# def get_eye_direction(landmarks, iw):
#     try:
#         right_iris_center = landmarks[468]  # Iris center
#         right_eye_inner = landmarks[133]
#         right_eye_outer = landmarks[33]

#         eye_width = right_eye_outer[0] - right_eye_inner[0]
#         if eye_width == 0:
#             return "Undetected"

#         iris_relative_pos = (right_iris_center[0] - right_eye_inner[0]) / eye_width

#         if iris_relative_pos < 0.35:
#             return "Looking Left"
#         elif iris_relative_pos > 0.65:
#             return "Looking Right"
#         else:
#             return "Looking Center"
#     except:
#         return "Undetected"

# print("Press 'q' to quit.")

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break

#     frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#     results = model(frame)

#     for box in results[0].boxes.xyxy:
#         x1, y1, x2, y2 = map(int, box)
#         face = frame[y1:y2, x1:x2]

#         if face.shape[0] == 0 or face.shape[1] == 0:
#             continue

#         face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
#         result_mesh = face_mesh.process(face_rgb)

#         if result_mesh.multi_face_landmarks:
#             for landmarks in result_mesh.multi_face_landmarks:
#                 ih, iw, _ = face.shape
#                 coords = [(p.x * iw, p.y * ih) for p in landmarks.landmark]

#                 try:
#                     angles = get_head_pose(face, coords)
#                     pitch, yaw, roll = [a[0] for a in angles]
#                     if abs(yaw) > 5:
#                         cheat = "⚠️ Head turned!"
#                         print(f"Yaw: {yaw:.2f} - Cheat: {cheat}")
#                     elif abs(pitch) > 7:
#                         cheat = "⚠️ Looking up/down!"
#                         print(f"Pitch: {pitch:.2f} - Cheat: {cheat}")
#                     else:
#                         cheat = ""
#                 except:
#                     cheat = "Head Pose Error"
#                     print("Head Pose Error")

#                 eye_dir = get_eye_direction(coords, iw)
#                 if eye_dir != "Looking Center":
#                     cheat = f"⚠️ {eye_dir}"
#                     print(f"Eye Direction: {eye_dir} - Cheat: {cheat}")
#                 else:
#                     cheat = ""
#                     print("Eye Direction: Looking Center")

#                 # Draw box and alert
#                 cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
#                 cv2.putText(frame, eye_dir, (x1, y1 - 10),
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
#                 if cheat:
#                     cv2.putText(frame, cheat, (x1, y2 + 20),
#                                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

#     cv2.imshow("YOLO + MediaPipe Cheat Detection", frame)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()

# %%
#just for direction but jub me left dekh rha hun to bta sahi rha h looking right the issue is k wo bta k phir center hi bta rha h k 
#phle looking right phir jldi me looking left 

import cv2
import numpy as np
from ultralytics import YOLO
import mediapipe as mp

# Load YOLO model
model = YOLO("yolov8n.pt")  # Use a face-trained model if you have one

# Initialize webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Cannot open webcam.")
    exit()

# Initialize MediaPipe Face Mesh
mp_face_mesh = mp.solutions.face_mesh
face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False,
                                  max_num_faces=1,
                                  refine_landmarks=True,
                                  min_detection_confidence=0.5,
                                  min_tracking_confidence=0.5)

def get_head_pose(image, landmarks):
    image_points = np.array([
        landmarks[1],    # Nose tip
        landmarks[152],  # Chin
        landmarks[33],   # Right eye outer corner
        landmarks[263],  # Left eye outer corner
        landmarks[78],   # Right mouth corner
        landmarks[308]   # Left mouth corner
    ], dtype="double")

    model_points = np.array([
        (0.0, 0.0, 0.0),             # Nose tip
        (0.0, -330.0, -65.0),        # Chin
        (225.0, 170.0, -135.0),      # Right eye outer corner
        (-225.0, 170.0, -135.0),     # Left eye outer corner
        (150.0, -150.0, -125.0),     # Right mouth corner
        (-150.0, -150.0, -125.0)     # Left mouth corner
    ])

    focal_length = image.shape[1]
    center = (image.shape[1] / 2, image.shape[0] / 2)
    camera_matrix = np.array([
        [focal_length, 0, center[0]],
        [0, focal_length, center[1]],
        [0, 0, 1]
    ], dtype="double")

    dist_coeffs = np.zeros((4, 1))
    success, rvec, _, _ = cv2.solvePnPRansac(
        model_points, image_points, camera_matrix, dist_coeffs)

    rmat, _ = cv2.Rodrigues(rvec)
    proj_matrix = np.hstack((rmat, np.zeros((3, 1))))
    _, _, _, _, _, _, angles = cv2.decomposeProjectionMatrix(proj_matrix)

    return angles  # pitch, yaw, roll

def get_eye_direction(landmarks, iw):
    left_eye = landmarks[263]  # left eye outer
    right_eye = landmarks[33]  # right eye outer
    eye_mid_x = (left_eye[0] + right_eye[0]) / 2
    eye_mid_x_norm = eye_mid_x / iw  # Normalize to 0-1 range

    if eye_mid_x_norm < 0.45:
        return "Looking Left"
    elif eye_mid_x_norm > 0.55:
        return "Looking Right"
    else:
        return "Looking Center"

print("Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = model(frame)

    for box in results[0].boxes.xyxy:
        x1, y1, x2, y2 = map(int, box)
        face = frame[y1:y2, x1:x2]

        if face.shape[0] == 0 or face.shape[1] == 0:
            continue

        face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
        result_mesh = face_mesh.process(face_rgb)

        if result_mesh.multi_face_landmarks:
            for landmarks in result_mesh.multi_face_landmarks:
                ih, iw, _ = face.shape
                coords = [(p.x * iw, p.y * ih) for p in landmarks.landmark]

                try:
                    angles = get_head_pose(face, coords)
                    pitch, yaw, roll = [a[0] for a in angles]
                    if abs(yaw) > 5:
                        cheat = "⚠️ Head turned!"
                        print(f"Yaw: {yaw:.2f} - Cheat: {cheat}")
                    elif abs(pitch) > 7:
                        cheat = "⚠️ Looking up/down!"
                        print(f"Pitch: {pitch:.2f} - Cheat: {cheat}")
                    else:
                        cheat = ""
                except:
                    cheat = "Head Pose Error"
                    print("Head Pose Error")

                eye_dir = get_eye_direction(coords, iw)
                if eye_dir != "Looking Center":
                    cheat = f"⚠️ {eye_dir}"
                    print(f"Eye Direction: {eye_dir} - Cheat: {cheat}")
                else:
                    cheat = ""
                    print("Eye Direction: Looking Center")

                # Draw box and alert
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame, eye_dir, (x1, y1 - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
                if cheat:
                    cv2.putText(frame, cheat, (x1, y2 + 20),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

    cv2.imshow("YOLO + MediaPipe Cheat Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'q' to quit.
#
# 0: 480x640 1 person, 2742.2ms
# Speed: 19.9ms preprocess, 2742.2ms inference, 12.4ms postprocess per image at shape (1, 3, 480, 640)
# Eye Direction: Looking Center
#
# 0: 480x640 1 person, 247.9ms
# Speed: 4.9ms preprocess, 247.9ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Head Pose Error
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 214.9ms
# Speed: 3.3ms preprocess, 214.9ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 1 tie, 419.3ms
# Speed: 5.8ms preprocess, 419.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 210.1ms
# Speed: 3.9ms preprocess, 210.1ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 228.9ms
# Speed: 3.9ms preprocess, 228.9ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: 15.36 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left
#
# 0: 480x640 1 person, 212.5ms
# Speed: 4.0ms preprocess, 212.5ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
# Yaw: -19.79 - Cheat: ⚠️ Head turned!
# Eye Direction: Looking Left - Cheat: ⚠️ Looking Left

# %%
# #just for direction

# import cv2
# import numpy as np
# from ultralytics import YOLO
# import mediapipe as mp

# # Load YOLO model
# model = YOLO("yolov8n.pt")  # Use a face-trained model if you have one

# # Initialize webcam
# cap = cv2.VideoCapture(0)
# if not cap.isOpened():
#     print("Error: Cannot open webcam.")
#     exit()

# # Initialize MediaPipe Face Mesh
# mp_face_mesh = mp.solutions.face_mesh
# face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False,
#                                   max_num_faces=1,
#                                   refine_landmarks=True,
#                                   min_detection_confidence=0.5,
#                                   min_tracking_confidence=0.5)

# def get_head_pose(image, landmarks):
#     image_points = np.array([
#         landmarks[1],    # Nose tip
#         landmarks[152],  # Chin
#         landmarks[33],   # Right eye outer corner
#         landmarks[263],  # Left eye outer corner
#         landmarks[78],   # Right mouth corner
#         landmarks[308]   # Left mouth corner
#     ], dtype="double")

#     model_points = np.array([
#         (0.0, 0.0, 0.0),             # Nose tip
#         (0.0, -330.0, -65.0),        # Chin
#         (225.0, 170.0, -135.0),      # Right eye outer corner
#         (-225.0, 170.0, -135.0),     # Left eye outer corner
#         (150.0, -150.0, -125.0),     # Right mouth corner
#         (-150.0, -150.0, -125.0)     # Left mouth corner
#     ])

#     focal_length = image.shape[1]
#     center = (image.shape[1] / 2, image.shape[0] / 2)
#     camera_matrix = np.array([
#         [focal_length, 0, center[0]],
#         [0, focal_length, center[1]],
#         [0, 0, 1]
#     ], dtype="double")

#     dist_coeffs = np.zeros((4, 1))
#     success, rvec, _, _ = cv2.solvePnPRansac(
#         model_points, image_points, camera_matrix, dist_coeffs)

#     rmat, _ = cv2.Rodrigues(rvec)
#     proj_matrix = np.hstack((rmat, np.zeros((3, 1))))
#     _, _, _, _, _, _, angles = cv2.decomposeProjectionMatrix(proj_matrix)

#     return angles  # pitch, yaw, roll

# def get_eye_direction(landmarks, iw):
#     left_eye = landmarks[263]  # left eye outer
#     right_eye = landmarks[33]  # right eye outer
#     eye_mid_x = (left_eye[0] + right_eye[0]) / 2
#     eye_mid_x_norm = eye_mid_x / iw  # Normalize to 0-1 range

#     if eye_mid_x_norm < 0.45:
#         return "Looking Left"
#     elif eye_mid_x_norm > 0.55:
#         return "Looking Right"
#     else:
#         return "Looking Center"

# print("Press 'q' to quit.")

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break

#     frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#     results = model(frame)

#     for box in results[0].boxes.xyxy:
#         x1, y1, x2, y2 = map(int, box)
#         face = frame[y1:y2, x1:x2]

#         if face.shape[0] == 0 or face.shape[1] == 0:
#             continue

#         face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
#         result_mesh = face_mesh.process(face_rgb)

#         if result_mesh.multi_face_landmarks:
#             for landmarks in result_mesh.multi_face_landmarks:
#                 ih, iw, _ = face.shape
#                 coords = [(p.x * iw, p.y * ih) for p in landmarks.landmark]

#                 try:
#                     angles = get_head_pose(face, coords)
#                     pitch, yaw, roll = [a[0] for a in angles]
#                     if abs(yaw) > 5:
#                         cheat = "⚠️ Head turned!"
#                         print(f"Yaw: {yaw:.2f} - Cheat: {cheat}")
#                     elif abs(pitch) > 7:
#                         cheat = "⚠️ Looking up/down!"
#                         print(f"Pitch: {pitch:.2f} - Cheat: {cheat}")
#                     else:
#                         cheat = ""
#                 except:
#                     cheat = "Head Pose Error"
#                     print("Head Pose Error")

#                 eye_dir = get_eye_direction(coords, iw)
#                 if eye_dir != "Looking Center":
#                     cheat = f"⚠️ {eye_dir}"
#                     print(f"Eye Direction: {eye_dir} - Cheat: {cheat}")
#                 else:
#                     cheat = ""
#                     print("Eye Direction: Looking Center")

#                 # Draw box and alert
#                 cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
#                 cv2.putText(frame, eye_dir, (x1, y1 - 10),
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
#                 if cheat:
#                     cv2.putText(frame, cheat, (x1, y2 + 20),
#                                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

#     cv2.imshow("YOLO + MediaPipe Cheat Detection", frame)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# from ultralytics import YOLO
# import mediapipe as mp

# # Load YOLO model
# model = YOLO("yolov8n.pt")  # Use a face-trained model if you have one

# # Initialize webcam
# cap = cv2.VideoCapture(0)
# if not cap.isOpened():
#     print("Error: Cannot open webcam.")
#     exit()

# # Initialize MediaPipe Face Mesh
# mp_face_mesh = mp.solutions.face_mesh
# face_mesh = mp_face_mesh.FaceMesh(static_image_mode=False,
#                                   max_num_faces=1,
#                                   refine_landmarks=True,
#                                   min_detection_confidence=0.5,
#                                   min_tracking_confidence=0.5)

# def get_head_pose(image, landmarks):
#     image_points = np.array([
#         landmarks[1],    # Nose tip
#         landmarks[152],  # Chin
#         landmarks[150],  # Right eye right corner
#         landmarks[11],   # Left eye left corner
#         landmarks[287],  # Right mouth corner
#         landmarks[57]    # Left mouth corner
#     ], dtype="double")

#     model_points = np.array([
#         (0.0, 0.0, 0.0),             # Nose tip
#         (0.0, -330.0, -65.0),        # Chin
#         (225.0, 170.0, -135.0),      # Right eye
#         (-225.0, 170.0, -135.0),     # Left eye
#         (150.0, -150.0, -125.0),     # Right mouth
#         (-150.0, -150.0, -125.0)     # Left mouth
#     ])

#     focal_length = image.shape[1]
#     center = (image.shape[1] / 2, image.shape[0] / 2)
#     camera_matrix = np.array([
#         [focal_length, 0, center[0]],
#         [0, focal_length, center[1]],
#         [0, 0, 1]
#     ], dtype="double")

#     dist_coeffs = np.zeros((4, 1))
#     success, rvec, _, _ = cv2.solvePnPRansac(
#         model_points, image_points, camera_matrix, dist_coeffs)

#     rmat, _ = cv2.Rodrigues(rvec)
#     proj_matrix = np.hstack((rmat, np.zeros((3, 1))))
#     _, _, _, _, _, _, angles = cv2.decomposeProjectionMatrix(proj_matrix)

#     return angles  # pitch, yaw, roll

# def get_eye_direction(landmarks, iw):
#     left_eye = landmarks[11]
#     right_eye = landmarks[200]
#     eye_mid_x = (left_eye[0] + right_eye[0]) / 2
#     eye_mid_x_norm = eye_mid_x / iw  # Normalize to 0-1 range

#     if eye_mid_x_norm < 0.4:
#         return "Looking Left"
#     elif eye_mid_x_norm > 0.6:
#         return "Looking Right"
#     else:
#         return "Looking Center"


# print("Press 'q' to quit.")

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break

#     frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#     results = model(frame)

#     for box in results[0].boxes.xyxy:
#         x1, y1, x2, y2 = map(int, box)
#         face = frame[y1:y2, x1:x2]

#         if face.shape[0] == 0 or face.shape[1] == 0:
#             continue

#         face_rgb = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)
#         result_mesh = face_mesh.process(face_rgb)

#         if result_mesh.multi_face_landmarks:
#             for landmarks in result_mesh.multi_face_landmarks:
#                 ih, iw, _ = face.shape
#                 coords = [(int(p.x * iw), int(p.y * ih)) for p in landmarks.landmark]

#                 # Head pose estimation
#                 try:
#                     angles = get_head_pose(face, coords)
#                     pitch, yaw, roll = [a[0] for a in angles]
#                     if abs(yaw) > 20:
#                         cheat = "⚠️ Head turned!"
#                         print(f"Yaw: {yaw} - Cheat: {cheat} Head truned")
#                     elif abs(pitch) > 20:
#                         cheat = "⚠️ Looking up/down!"
#                         print(f"Pitch: {pitch} - Cheat: {cheat} Looking up/down")
#                     else:
#                         cheat = ""
#                 except:
#                     cheat = "Head Pose Error"
#                     print("Head Pose Error")

#                 # Eye direction
#                 # eye_dir = get_eye_direction(coords)
#                 eye_dir = get_eye_direction(coords, iw)
#                 if eye_dir != "Looking Center":
#                     cheat = f"⚠️ {eye_dir}"
#                     print(f"Eye Direction: {eye_dir} - Cheat: {cheat}")
#                 else:
#                     cheat = ""
#                     print("Eye Direction: Looking Center")

#                 # Draw box and alert
#                 cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
#                 cv2.putText(frame, eye_dir, (x1, y1 - 10),
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 255, 0), 2)
#                 if cheat:
#                     cv2.putText(frame, cheat, (x1, y2 + 20),
#                                 cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

#     cv2.imshow("YOLO + MediaPipe Cheat Detection", frame)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()
